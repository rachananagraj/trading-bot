# %% [markdown]
# ## **Project: Live Trading Bot**
#
# **Project Summary:**
#
# Trading has become an important sector for investors to invest in.
#
# In order to earn profit from stocks or cryptocurrency,  the investor has to make sure to dedicate enough time by checking the market rates for these stocks. investors cannot dedicate 24 hours to monitoring the market. This reduces their chances of doing a profitable transaction at any given point of time.
#
# Various aspects that restraining the efficacy of humans in trading in several ways.
#
# 1.   The reaction time of the investors.
# 2.   Price fluctuation

# %% [markdown]
# ### Install necessary libararies

# %%
# !pip install stable_baselines3 wandb mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stable_baselines3 in /usr/local/lib/python3.9/dist-packages (1.7.0)
# Requirement already satisfied: wandb in /usr/local/lib/python3.9/dist-packages (0.14.0)
# Requirement already satisfied: mplfinance in /usr/local/lib/python3.9/dist-packages (0.12.9b7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (3.7.1)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (1.13.1+cu116)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (1.4.4)
# Requirement already satisfied: importlib-metadata~=4.13 in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (4.13.0)
# Requirement already satisfied: gym==0.21 in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (0.21.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (1.22.4)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from wandb) (63.4.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (5.9.4)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.9/dist-packages (from wandb) (1.3.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.15.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.19.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.9/dist-packages (from wandb) (6.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (8.1.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.17.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (3.1.31)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.9/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.9/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from wandb) (4.5.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.9/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.9/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata~=4.13->stable_baselines3) (3.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->stable_baselines3) (8.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->stable_baselines3) (2022.7.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.0)

# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import glob

# %% [markdown]
# ##Cloning the github repository - Reinforcement-learning-Live-Trading for DEMO.

# %%
# !git clone https://github.com/rachananagraj/trading-bot.git
# Out:
# fatal: destination path 'trading-bot' already exists and is not an empty directory.

# %% [markdown]
# ## Read Stock data for AAPL and merge them into one dataset.

# %% [markdown]
# Change the directory

# %%
cd /content/trading-bot
# Out:
# /content/trading-bot

# %% [markdown]
# Merge all the stock data for AAPL into final csv file for learning.

# %%
df = pd.concat([pd.read_csv(f, sep=',') for f in glob.glob('data' + "/AAPL_2*.csv")],
                      ignore_index=True)

# %%
df.head()
# Out:
#          Date    Open    High     Low   Close       Volume
# 0  11/16/2020  118.92  120.99  118.15  120.30   91,183,023
# 1  11/13/2020  119.44  119.67  117.87  119.26   81,688,594
# 2  11/12/2020  119.62  120.53  118.57  119.21  103,350,703
# 3  11/11/2020  117.19  119.63  116.44  119.49  112,295,000
# 4  11/10/2020  115.55  117.59  114.13  115.97  138,023,391

# %%
df.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume     object
# dtype: object

# %% [markdown]
# Convert data field as datetime.

# %%
df['Date'] = pd.to_datetime(df ['Date'])

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume            object
# dtype: object

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close       Volume
# 0 2020-11-16  118.92  120.99  118.15  120.30   91,183,023
# 1 2020-11-13  119.44  119.67  117.87  119.26   81,688,594
# 2 2020-11-12  119.62  120.53  118.57  119.21  103,350,703
# 3 2020-11-11  117.19  119.63  116.44  119.49  112,295,000
# 4 2020-11-10  115.55  117.59  114.13  115.97  138,023,391

# %% [markdown]
# We need to convert the values from string to float type. Otherwise, it won't work.

# %%
df['Volume'] = df['Volume'].apply(lambda x: float(x.replace(",", "")))

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close       Volume
# 0 2020-11-16  118.92  120.99  118.15  120.30   91183023.0
# 1 2020-11-13  119.44  119.67  117.87  119.26   81688594.0
# 2 2020-11-12  119.62  120.53  118.57  119.21  103350703.0
# 3 2020-11-11  117.19  119.63  116.44  119.49  112295000.0
# 4 2020-11-10  115.55  117.59  114.13  115.97  138023391.0

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df = df.sort_values('Date')
df.head()
# Out:
#           Date   Open   High    Low  Close       Volume
# 502 2018-11-19  47.50  47.68  46.25  46.47  167683484.0
# 501 2018-11-20  44.59  45.37  43.88  44.25  271301000.0
# 500 2018-11-21  44.93  45.07  44.14  44.20  124496844.0
# 499 2018-11-23  43.74  44.15  43.03  43.07   94495884.0
# 498 2018-11-26  43.56  43.74  42.57  43.66  179994080.0

# %%
df.to_csv('data/AAPl.csv',index=False)

# %%
new_df = pd.read_csv('data/AAPL.csv')
new_df
# Out:
#            Date    Open    High     Low   Close       Volume
# 0    2018-11-19   47.50   47.68   46.25   46.47  167683484.0
# 1    2018-11-20   44.59   45.37   43.88   44.25  271301000.0
# 2    2018-11-21   44.93   45.07   44.14   44.20  124496844.0
# 3    2018-11-23   43.74   44.15   43.03   43.07   94495884.0
# 4    2018-11-26   43.56   43.74   42.57   43.66  179994080.0
# ..          ...     ...     ...     ...     ...          ...
# 995  2022-10-28  148.20  157.50  147.82  155.74  164762406.0
# 996  2022-10-31  153.16  154.24  151.92  153.34   97943172.0
# 997  2022-11-01  155.08  155.45  149.13  150.65   80379352.0
# 998  2022-11-02  148.95  152.17  145.00  145.03   93604625.0
# 999  2022-11-03  142.06  142.80  138.75  138.88   97918523.0
#
# [1000 rows x 6 columns]

# %%
pwd
# Out:
# '/content/trading-bot'

# %% [markdown]
# ## Stock-Trading Inferences by running different algorithms -

# %% [markdown]
# # A - PPO ALgorithm - Proximal Policy Optimization(PPO).
#
# PPO is a policy gradient method where policy is updated explicitly. We can write the objective function or loss function of vanilla policy gradient with advantage function.

# %% [markdown]
# ### Experiment#1 - **PPO over 100000 steps**
#
# Experiment PPO algo with default params - gamma=0.99 , learning_rate=0.0007 , ent_coef=0.4

# %%
from stocktrade import Stocktrade

if __name__ == "__main__":
    timesteps = 100000
    algo = "PPO"
    Stocktrade.stocktrade(algo,timesteps)
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_190144-23rge3jr</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/23rge3jr' target="_blank">ethereal-rain-35</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/23rge3jr' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/23rge3jr</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# Using cuda device
# Logging to runs/23rge3jr/PPO_1
# /content/trading-bot/env/stock_trading_env.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   self.cost_basis = (
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 99   |
# |    iterations      | 1    |
# |    time_elapsed    | 20   |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 3000          |
# | train/                  |               |
# |    approx_kl            | 1.3238343e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.73e+08      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000213     |
# |    std                  | 1             |
# |    value_loss           | 7.86e+08      |
# -------------------------------------------
# Eval num_timesteps=4000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 105  |
# |    iterations      | 2    |
# |    time_elapsed    | 38   |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=5000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 5000          |
# | train/                  |               |
# |    approx_kl            | 2.5898335e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.16e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.02e+08      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -7.52e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.15e+09      |
# -------------------------------------------
# Eval num_timesteps=6000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 106  |
# |    iterations      | 3    |
# |    time_elapsed    | 57   |
# |    total_timesteps | 6144 |
# -----------------------------
# Eval num_timesteps=7000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 7000         |
# | train/                  |              |
# |    approx_kl            | 4.537287e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 6.44e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.59e+08     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000138    |
# |    std                  | 1            |
# |    value_loss           | 7.21e+08     |
# ------------------------------------------
# Eval num_timesteps=8000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 107  |
# |    iterations      | 4    |
# |    time_elapsed    | 75   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=9000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 9000          |
# | train/                  |               |
# |    approx_kl            | 2.7919305e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 2.8e-06       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.87e+08      |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -6.84e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.51e+08      |
# -------------------------------------------
# Eval num_timesteps=10000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 5     |
# |    time_elapsed    | 94    |
# |    total_timesteps | 10240 |
# ------------------------------
# Eval num_timesteps=11000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 3e+06       |
# | time/                   |             |
# |    total_timesteps      | 11000       |
# | train/                  |             |
# |    approx_kl            | 7.77276e-07 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 1.55e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.45e+08    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -2.12e-05   |
# |    std                  | 1           |
# |    value_loss           | 1.02e+09    |
# -----------------------------------------
# Eval num_timesteps=12000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 12000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 6     |
# |    time_elapsed    | 113   |
# |    total_timesteps | 12288 |
# ------------------------------
# Eval num_timesteps=13000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 13000         |
# | train/                  |               |
# |    approx_kl            | 1.9892468e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.25e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.88e+08      |
# |    n_updates            | 60            |
# |    policy_gradient_loss | -6.29e-05     |
# |    std                  | 1             |
# |    value_loss           | 8.47e+08      |
# -------------------------------------------
# Eval num_timesteps=14000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 7     |
# |    time_elapsed    | 131   |
# |    total_timesteps | 14336 |
# ------------------------------
# Eval num_timesteps=15000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 15000         |
# | train/                  |               |
# |    approx_kl            | 1.0620861e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.96e+08      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -3.55e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.3e+09       |
# -------------------------------------------
# Eval num_timesteps=16000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 16000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 8     |
# |    time_elapsed    | 150   |
# |    total_timesteps | 16384 |
# ------------------------------
# Eval num_timesteps=17000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 17000        |
# | train/                  |              |
# |    approx_kl            | 8.885603e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 4.17e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.97e+08     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000226    |
# |    std                  | 1            |
# |    value_loss           | 1.02e+09     |
# ------------------------------------------
# Eval num_timesteps=18000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 18000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 9     |
# |    time_elapsed    | 168   |
# |    total_timesteps | 18432 |
# ------------------------------
# Eval num_timesteps=19000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 19000         |
# | train/                  |               |
# |    approx_kl            | 1.6032718e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.03e+08      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -6.02e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.33e+08      |
# -------------------------------------------
# Eval num_timesteps=20000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 10    |
# |    time_elapsed    | 187   |
# |    total_timesteps | 20480 |
# ------------------------------
# Eval num_timesteps=21000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 21000         |
# | train/                  |               |
# |    approx_kl            | 1.5316764e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 4.77e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.83e+08      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -5.97e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.03e+09      |
# -------------------------------------------
# Eval num_timesteps=22000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 22000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 11    |
# |    time_elapsed    | 206   |
# |    total_timesteps | 22528 |
# ------------------------------
# Eval num_timesteps=23000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 23000         |
# | train/                  |               |
# |    approx_kl            | 1.9854633e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.47e+08      |
# |    n_updates            | 110           |
# |    policy_gradient_loss | -5.53e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 8.73e+08      |
# -------------------------------------------
# Eval num_timesteps=24000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 24000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 12    |
# |    time_elapsed    | 224   |
# |    total_timesteps | 24576 |
# ------------------------------
# Eval num_timesteps=25000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 25000         |
# | train/                  |               |
# |    approx_kl            | 2.3395696e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 2.38e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.85e+08      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -6.53e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.17e+09      |
# -------------------------------------------
# Eval num_timesteps=26000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 26000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 13    |
# |    time_elapsed    | 243   |
# |    total_timesteps | 26624 |
# ------------------------------
# Eval num_timesteps=27000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 27000        |
# | train/                  |              |
# |    approx_kl            | 6.703718e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.98e+08     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000166    |
# |    std                  | 1.01         |
# |    value_loss           | 7.31e+08     |
# ------------------------------------------
# Eval num_timesteps=28000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 28000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 14    |
# |    time_elapsed    | 262   |
# |    total_timesteps | 28672 |
# ------------------------------
# Eval num_timesteps=29000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 29000        |
# | train/                  |              |
# |    approx_kl            | 1.557346e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.97e+08     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -4.01e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 1.17e+09     |
# ------------------------------------------
# Eval num_timesteps=30000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 30000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 15    |
# |    time_elapsed    | 280   |
# |    total_timesteps | 30720 |
# ------------------------------
# Eval num_timesteps=31000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 31000        |
# | train/                  |              |
# |    approx_kl            | 1.078879e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 2.38e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.06e+08     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -5.07e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 1.28e+09     |
# ------------------------------------------
# Eval num_timesteps=32000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 32000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 16    |
# |    time_elapsed    | 299   |
# |    total_timesteps | 32768 |
# ------------------------------
# Eval num_timesteps=33000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 33000         |
# | train/                  |               |
# |    approx_kl            | 2.1925953e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.65e+08      |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -6.51e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 8.82e+08      |
# -------------------------------------------
# Eval num_timesteps=34000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 34000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 17    |
# |    time_elapsed    | 318   |
# |    total_timesteps | 34816 |
# ------------------------------
# Eval num_timesteps=35000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 35000         |
# | train/                  |               |
# |    approx_kl            | 3.1114032e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.51e+08      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -9.16e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.7e+08       |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 36000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 18    |
# |    time_elapsed    | 337   |
# |    total_timesteps | 36864 |
# ------------------------------
# Eval num_timesteps=37000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 37000         |
# | train/                  |               |
# |    approx_kl            | 2.5797635e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.42e+08      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -8.03e-06     |
# |    std                  | 1.01          |
# |    value_loss           | 1.18e+09      |
# -------------------------------------------
# Eval num_timesteps=38000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 19    |
# |    time_elapsed    | 356   |
# |    total_timesteps | 38912 |
# ------------------------------
# Eval num_timesteps=39000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 39000         |
# | train/                  |               |
# |    approx_kl            | 1.4350226e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.3e+08       |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -4.18e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.32e+09      |
# -------------------------------------------
# Eval num_timesteps=40000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 40000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 20    |
# |    time_elapsed    | 375   |
# |    total_timesteps | 40960 |
# ------------------------------
# Eval num_timesteps=41000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 41000        |
# | train/                  |              |
# |    approx_kl            | 2.409739e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.82e+08     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -5.47e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 9.34e+08     |
# ------------------------------------------
# Eval num_timesteps=42000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 42000    |
# ---------------------------------
# Eval num_timesteps=43000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 43000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 21    |
# |    time_elapsed    | 400   |
# |    total_timesteps | 43008 |
# ------------------------------
# Eval num_timesteps=44000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 44000         |
# | train/                  |               |
# |    approx_kl            | 3.0081137e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.59e+08      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -9.19e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1e+09         |
# -------------------------------------------
# Eval num_timesteps=45000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 45000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 22    |
# |    time_elapsed    | 419   |
# |    total_timesteps | 45056 |
# ------------------------------
# Eval num_timesteps=46000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 46000         |
# | train/                  |               |
# |    approx_kl            | 7.2977855e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.75e+08      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -2.11e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 8.26e+08      |
# -------------------------------------------
# Eval num_timesteps=47000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 47000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 23    |
# |    time_elapsed    | 438   |
# |    total_timesteps | 47104 |
# ------------------------------
# Eval num_timesteps=48000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 3e+06       |
# | time/                   |             |
# |    total_timesteps      | 48000       |
# | train/                  |             |
# |    approx_kl            | 5.51471e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.3e+08     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.000116   |
# |    std                  | 1.01        |
# |    value_loss           | 9.38e+08    |
# -----------------------------------------
# Eval num_timesteps=49000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 49000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 24    |
# |    time_elapsed    | 457   |
# |    total_timesteps | 49152 |
# ------------------------------
# Eval num_timesteps=50000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 50000         |
# | train/                  |               |
# |    approx_kl            | 1.3386889e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.28e+08      |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -4.93e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.4e+08       |
# -------------------------------------------
# Eval num_timesteps=51000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 51000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 25    |
# |    time_elapsed    | 476   |
# |    total_timesteps | 51200 |
# ------------------------------
# Eval num_timesteps=52000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 52000         |
# | train/                  |               |
# |    approx_kl            | 5.6865974e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.93e+08      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -1.62e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.39e+09      |
# -------------------------------------------
# Eval num_timesteps=53000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 53000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 26    |
# |    time_elapsed    | 495   |
# |    total_timesteps | 53248 |
# ------------------------------
# Eval num_timesteps=54000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 54000        |
# | train/                  |              |
# |    approx_kl            | 4.059286e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.28e+08     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -9.1e-05     |
# |    std                  | 1.01         |
# |    value_loss           | 8.49e+08     |
# ------------------------------------------
# Eval num_timesteps=55000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 55000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 27    |
# |    time_elapsed    | 514   |
# |    total_timesteps | 55296 |
# ------------------------------
# Eval num_timesteps=56000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 56000         |
# | train/                  |               |
# |    approx_kl            | 1.5626138e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.57e+08      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -5.89e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.59e+08      |
# -------------------------------------------
# Eval num_timesteps=57000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 57000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 28    |
# |    time_elapsed    | 533   |
# |    total_timesteps | 57344 |
# ------------------------------
# Eval num_timesteps=58000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 3e+06       |
# | time/                   |             |
# |    total_timesteps      | 58000       |
# | train/                  |             |
# |    approx_kl            | 2.63119e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.33e+08    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -6.7e-05    |
# |    std                  | 1.01        |
# |    value_loss           | 9.64e+08    |
# -----------------------------------------
# Eval num_timesteps=59000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 59000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 29    |
# |    time_elapsed    | 552   |
# |    total_timesteps | 59392 |
# ------------------------------
# Eval num_timesteps=60000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 2.7061033e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.81e+08      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.93e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.2e+09       |
# -------------------------------------------
# Eval num_timesteps=61000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 61000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 30    |
# |    time_elapsed    | 571   |
# |    total_timesteps | 61440 |
# ------------------------------
# Eval num_timesteps=62000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 62000         |
# | train/                  |               |
# |    approx_kl            | 2.3997854e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.02e+08      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -5.96e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 7.34e+08      |
# -------------------------------------------
# Eval num_timesteps=63000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 63000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 31    |
# |    time_elapsed    | 591   |
# |    total_timesteps | 63488 |
# ------------------------------
# Eval num_timesteps=64000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 64000        |
# | train/                  |              |
# |    approx_kl            | 4.569418e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.87        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.02e+08     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -9.93e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 8.22e+08     |
# ...
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.02e+08    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -2.89e-05   |
# |    std                  | 1.02        |
# |    value_loss           | 1.16e+09    |
# -----------------------------------------
# Eval num_timesteps=83000, episode_reward=2343118.95 +/- 4457.71
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.34e+06 |
# | time/              |          |
# |    total_timesteps | 83000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 41    |
# |    time_elapsed    | 780   |
# |    total_timesteps | 83968 |
# ------------------------------
# Eval num_timesteps=84000, episode_reward=2443433.55 +/- 3976.30
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.44e+06      |
# | time/                   |               |
# |    total_timesteps      | 84000         |
# | train/                  |               |
# |    approx_kl            | 3.3263932e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.35e+08      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -0.000117     |
# |    std                  | 1.02          |
# |    value_loss           | 7.54e+08      |
# -------------------------------------------
# Eval num_timesteps=85000, episode_reward=2443607.05 +/- 3865.60
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.44e+06 |
# | time/              |          |
# |    total_timesteps | 85000    |
# ---------------------------------
# Eval num_timesteps=86000, episode_reward=2441260.01 +/- 444.24
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.44e+06 |
# | time/              |          |
# |    total_timesteps | 86000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 42    |
# |    time_elapsed    | 806   |
# |    total_timesteps | 86016 |
# ------------------------------
# Eval num_timesteps=87000, episode_reward=2494390.53 +/- 486.08
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.49e+06      |
# | time/                   |               |
# |    total_timesteps      | 87000         |
# | train/                  |               |
# |    approx_kl            | 1.1195079e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.39e+08      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -3.74e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.07e+09      |
# -------------------------------------------
# Eval num_timesteps=88000, episode_reward=2494693.16 +/- 358.46
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.49e+06 |
# | time/              |          |
# |    total_timesteps | 88000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 43    |
# |    time_elapsed    | 824   |
# |    total_timesteps | 88064 |
# ------------------------------
# Eval num_timesteps=89000, episode_reward=2295364.78 +/- 4993.81
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.3e+06       |
# | time/                   |               |
# |    total_timesteps      | 89000         |
# | train/                  |               |
# |    approx_kl            | 1.8170394e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.79e+08      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -5.98e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.24e+09      |
# -------------------------------------------
# Eval num_timesteps=90000, episode_reward=2297587.75 +/- 5361.22
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.3e+06  |
# | time/              |          |
# |    total_timesteps | 90000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 44    |
# |    time_elapsed    | 842   |
# |    total_timesteps | 90112 |
# ------------------------------
# Eval num_timesteps=91000, episode_reward=2420396.83 +/- 434.74
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.42e+06      |
# | time/                   |               |
# |    total_timesteps      | 91000         |
# | train/                  |               |
# |    approx_kl            | 1.1159573e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.76e+08      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -4.86e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 8.67e+08      |
# -------------------------------------------
# Eval num_timesteps=92000, episode_reward=2420224.66 +/- 255.75
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.42e+06 |
# | time/              |          |
# |    total_timesteps | 92000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 45    |
# |    time_elapsed    | 862   |
# |    total_timesteps | 92160 |
# ------------------------------
# Eval num_timesteps=93000, episode_reward=2525578.80 +/- 214.34
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.53e+06      |
# | time/                   |               |
# |    total_timesteps      | 93000         |
# | train/                  |               |
# |    approx_kl            | 2.9056391e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.25e+08      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -8.52e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 6.98e+08      |
# -------------------------------------------
# Eval num_timesteps=94000, episode_reward=2525616.92 +/- 341.19
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.53e+06 |
# | time/              |          |
# |    total_timesteps | 94000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 46    |
# |    time_elapsed    | 880   |
# |    total_timesteps | 94208 |
# ------------------------------
# Eval num_timesteps=95000, episode_reward=2525597.46 +/- 138.36
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.53e+06      |
# | time/                   |               |
# |    total_timesteps      | 95000         |
# | train/                  |               |
# |    approx_kl            | 5.3897384e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.32e+08      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -1.68e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 7.69e+08      |
# -------------------------------------------
# Eval num_timesteps=96000, episode_reward=2525544.65 +/- 358.15
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.53e+06 |
# | time/              |          |
# |    total_timesteps | 96000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 47    |
# |    time_elapsed    | 900   |
# |    total_timesteps | 96256 |
# ------------------------------
# Eval num_timesteps=97000, episode_reward=2525422.67 +/- 394.36
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.53e+06      |
# | time/                   |               |
# |    total_timesteps      | 97000         |
# | train/                  |               |
# |    approx_kl            | 4.8964575e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.31e+08      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -0.000117     |
# |    std                  | 1.02          |
# |    value_loss           | 8.97e+08      |
# -------------------------------------------
# Eval num_timesteps=98000, episode_reward=2525558.51 +/- 422.72
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.53e+06 |
# | time/              |          |
# |    total_timesteps | 98000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 48    |
# |    time_elapsed    | 919   |
# |    total_timesteps | 98304 |
# ------------------------------
# Eval num_timesteps=99000, episode_reward=2573281.88 +/- 4670.25
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.57e+06      |
# | time/                   |               |
# |    total_timesteps      | 99000         |
# | train/                  |               |
# |    approx_kl            | 1.2821401e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.64e+08      |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -3.7e-05      |
# |    std                  | 1.02          |
# |    value_loss           | 1.23e+09      |
# -------------------------------------------
# Eval num_timesteps=100000, episode_reward=2574329.53 +/- 4755.77
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.57e+06 |
# | time/              |          |
# |    total_timesteps | 100000   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 106    |
# |    iterations      | 49     |
# |    time_elapsed    | 941    |
# |    total_timesteps | 100352 |
# -------------------------------
# mean_reward:2566484.26 +/- 5483.45
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/mean_reward</td><td>███████████████████████████▅▅▂▁▂▂▃▄▂▃▄▄▄</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>▁▅▆▇▇████████████▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆</td></tr><tr><td>train/approx_kl</td><td>█▂▃▂▁▁▆▂▂▂▄▂▁▂▂▁▂▂▁▄▁▃▂▂▂▃▁▃▂▂▁▁▁▁▃▂▁▂▁▁</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>███▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▂▁▂▂▂▂▁▁</td></tr><tr><td>train/explained_variance</td><td>▁█▅▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▂▄▂▂▂▄▂▃▂▂▂▄▃▂▂▃▂▃▁▂▄▂▃▂▂▂▃▂▂▂█▅▄▂▁▂▃▂▂▃</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▆▄▆█▇▁▇▇▇▃▇▇▆▅▇▇▅█▅█▅▇▆▆▅▇▄▅▅▇▇▇█▅▇▇▆█▇</td></tr><tr><td>train/std</td><td>▁▁▁▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇▇█▇▇▇▇███</td></tr><tr><td>train/value_loss</td><td>▂▄▁▂▃▅▃▃▃▂▁▄▅▂▃▅▃▃▂▃▅▂▃▃▄▂▂▁▃▃█▇▅▄▁▄▂▁▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>1000.0</td></tr><tr><td>eval/mean_reward</td><td>2574329.5</td></tr><tr><td>global_step</td><td>100352</td></tr><tr><td>time/fps</td><td>106.0</td></tr><tr><td>train/approx_kl</td><td>0.0</td></tr><tr><td>train/clip_fraction</td><td>0.0</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-2.87625</td></tr><tr><td>train/explained_variance</td><td>-0.0</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>564319616.0</td></tr><tr><td>train/policy_gradient_loss</td><td>-4e-05</td></tr><tr><td>train/std</td><td>1.01949</td></tr><tr><td>train/value_loss</td><td>1229483392.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-rain-35</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/23rge3jr' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/23rge3jr</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_190144-23rge3jr/logs</code>

# %% [markdown]
# ### Experiment#2 - PPO over 100000 steps (Hyper Parameter Tuning)
#
# **Experiment PPO algo with gamma=0.8 , learning_rate=0.0007 , ent_coef=0.3**

# %%
#### 6.2  Running PPO algorithm over 100 time steps
from stocktrade1 import Stocktrade

if __name__ == "__main__":
    timesteps = 100000
    algo = "PPO"
    hyper_param = True
    Stocktrade.stocktrade(algo,timesteps,hyper_param)
# Out:
# wandb: Currently logged in as: rachanakukkikatte21. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_191819-eozno2tt</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/eozno2tt' target="_blank">azure-energy-36</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/eozno2tt' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/eozno2tt</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cuda device
# Logging to runs/eozno2tt/PPO_1
# /content/trading-bot/env/stock_trading_env.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   self.cost_basis = (
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=1000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 1000     |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 2000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 115  |
# |    iterations      | 1    |
# |    time_elapsed    | 17   |
# |    total_timesteps | 2048 |
# -----------------------------
# Eval num_timesteps=3000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 3000          |
# | train/                  |               |
# |    approx_kl            | 6.6760113e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.93e+08      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000128     |
# |    std                  | 1             |
# |    value_loss           | 1.23e+09      |
# -------------------------------------------
# Eval num_timesteps=4000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 4000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 112  |
# |    iterations      | 2    |
# |    time_elapsed    | 36   |
# |    total_timesteps | 4096 |
# -----------------------------
# Eval num_timesteps=5000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 5000         |
# | train/                  |              |
# |    approx_kl            | 3.816065e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 1.14e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.37e+08     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.000113    |
# |    std                  | 1            |
# |    value_loss           | 1.1e+09      |
# ------------------------------------------
# Eval num_timesteps=6000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 6000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 110  |
# |    iterations      | 3    |
# |    time_elapsed    | 55   |
# |    total_timesteps | 6144 |
# -----------------------------
# Eval num_timesteps=7000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 7000          |
# | train/                  |               |
# |    approx_kl            | 3.7915306e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 4.95e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.67e+08      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -9.7e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.18e+09      |
# -------------------------------------------
# Eval num_timesteps=8000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 8000     |
# ---------------------------------
# -----------------------------
# | time/              |      |
# |    fps             | 109  |
# |    iterations      | 4    |
# |    time_elapsed    | 74   |
# |    total_timesteps | 8192 |
# -----------------------------
# Eval num_timesteps=9000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 9000         |
# | train/                  |              |
# |    approx_kl            | 6.541086e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 3.16e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.39e+08     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -2.05e-05    |
# |    std                  | 1            |
# |    value_loss           | 7.38e+08     |
# ------------------------------------------
# Eval num_timesteps=10000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 10000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 5     |
# |    time_elapsed    | 93    |
# |    total_timesteps | 10240 |
# ------------------------------
# Eval num_timesteps=11000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 11000         |
# | train/                  |               |
# |    approx_kl            | 2.1649175e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.25e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.43e+08      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -7.2e-05      |
# |    std                  | 1             |
# |    value_loss           | 1.36e+09      |
# -------------------------------------------
# Eval num_timesteps=12000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 12000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 6     |
# |    time_elapsed    | 112   |
# |    total_timesteps | 12288 |
# ------------------------------
# Eval num_timesteps=13000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 13000        |
# | train/                  |              |
# |    approx_kl            | 5.716749e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 1.31e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+08      |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000117    |
# |    std                  | 1.01         |
# |    value_loss           | 6.05e+08     |
# ------------------------------------------
# Eval num_timesteps=14000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 14000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 7     |
# |    time_elapsed    | 130   |
# |    total_timesteps | 14336 |
# ------------------------------
# Eval num_timesteps=15000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 15000         |
# | train/                  |               |
# |    approx_kl            | 2.1233282e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 5.96e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.18e+08      |
# |    n_updates            | 70            |
# |    policy_gradient_loss | -6.06e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.03e+09      |
# -------------------------------------------
# Eval num_timesteps=16000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 16000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 8     |
# |    time_elapsed    | 150   |
# |    total_timesteps | 16384 |
# ------------------------------
# Eval num_timesteps=17000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 17000         |
# | train/                  |               |
# |    approx_kl            | 1.2847013e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 4.77e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.48e+08      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -3.88e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.38e+08      |
# -------------------------------------------
# Eval num_timesteps=18000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 18000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 9     |
# |    time_elapsed    | 168   |
# |    total_timesteps | 18432 |
# ------------------------------
# Eval num_timesteps=19000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 19000         |
# | train/                  |               |
# |    approx_kl            | 1.9748986e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 4.17e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.92e+08      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -9.49e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.14e+09      |
# -------------------------------------------
# Eval num_timesteps=20000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 20000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 109   |
# |    iterations      | 10    |
# |    time_elapsed    | 187   |
# |    total_timesteps | 20480 |
# ------------------------------
# Eval num_timesteps=21000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 21000         |
# | train/                  |               |
# |    approx_kl            | 1.6227423e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 3.58e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.83e+08      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -5.16e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.09e+09      |
# -------------------------------------------
# Eval num_timesteps=22000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 22000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 11    |
# |    time_elapsed    | 207   |
# |    total_timesteps | 22528 |
# ------------------------------
# Eval num_timesteps=23000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 23000        |
# | train/                  |              |
# |    approx_kl            | 9.780924e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 2.98e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.97e+08     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -2.72e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 7.44e+08     |
# ------------------------------------------
# Eval num_timesteps=24000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 24000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 12    |
# |    time_elapsed    | 225   |
# |    total_timesteps | 24576 |
# ------------------------------
# Eval num_timesteps=25000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 25000        |
# | train/                  |              |
# |    approx_kl            | 1.357228e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.41e+08     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -5.47e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 8.01e+08     |
# ------------------------------------------
# Eval num_timesteps=26000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 26000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 13    |
# |    time_elapsed    | 245   |
# |    total_timesteps | 26624 |
# ------------------------------
# Eval num_timesteps=27000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 27000        |
# | train/                  |              |
# |    approx_kl            | 5.268317e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.56e+08     |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000143    |
# |    std                  | 1.01         |
# |    value_loss           | 9.74e+08     |
# ------------------------------------------
# Eval num_timesteps=28000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 28000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 14    |
# |    time_elapsed    | 263   |
# |    total_timesteps | 28672 |
# ------------------------------
# Eval num_timesteps=29000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 29000         |
# | train/                  |               |
# |    approx_kl            | 4.4336193e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.85         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.27e+08      |
# |    n_updates            | 140           |
# |    policy_gradient_loss | -0.000138     |
# |    std                  | 1.01          |
# |    value_loss           | 9.86e+08      |
# -------------------------------------------
# Eval num_timesteps=30000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 30000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 15    |
# |    time_elapsed    | 283   |
# |    total_timesteps | 30720 |
# ------------------------------
# Eval num_timesteps=31000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 31000        |
# | train/                  |              |
# |    approx_kl            | 2.027722e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.36e+08     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -7.05e-05    |
# |    std                  | 1.01         |
# |    value_loss           | 1.1e+09      |
# ------------------------------------------
# Eval num_timesteps=32000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 32000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 16    |
# |    time_elapsed    | 302   |
# |    total_timesteps | 32768 |
# ------------------------------
# Eval num_timesteps=33000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 33000        |
# | train/                  |              |
# |    approx_kl            | 7.399387e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.66e+08     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.000192    |
# |    std                  | 1.01         |
# |    value_loss           | 1.06e+09     |
# ------------------------------------------
# Eval num_timesteps=34000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 34000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 17    |
# |    time_elapsed    | 320   |
# |    total_timesteps | 34816 |
# ------------------------------
# Eval num_timesteps=35000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 35000         |
# | train/                  |               |
# |    approx_kl            | 2.8132927e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 1.79e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.66e+08      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -6.46e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 8.46e+08      |
# -------------------------------------------
# Eval num_timesteps=36000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 36000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 18    |
# |    time_elapsed    | 340   |
# |    total_timesteps | 36864 |
# ------------------------------
# Eval num_timesteps=37000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 37000         |
# | train/                  |               |
# |    approx_kl            | 3.5175763e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.05e+08      |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.000113     |
# |    std                  | 1.01          |
# |    value_loss           | 9.42e+08      |
# -------------------------------------------
# Eval num_timesteps=38000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 38000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 19    |
# |    time_elapsed    | 358   |
# |    total_timesteps | 38912 |
# ------------------------------
# Eval num_timesteps=39000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 39000         |
# | train/                  |               |
# |    approx_kl            | 8.5894135e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.43e+08      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -2.34e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.1e+08       |
# -------------------------------------------
# Eval num_timesteps=40000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 40000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 108   |
# |    iterations      | 20    |
# |    time_elapsed    | 378   |
# |    total_timesteps | 40960 |
# ------------------------------
# Eval num_timesteps=41000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 41000         |
# | train/                  |               |
# |    approx_kl            | 1.4510006e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.56e+08      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -5.56e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.24e+09      |
# -------------------------------------------
# Eval num_timesteps=42000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 42000    |
# ---------------------------------
# Eval num_timesteps=43000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 43000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 21    |
# |    time_elapsed    | 403   |
# |    total_timesteps | 43008 |
# ------------------------------
# Eval num_timesteps=44000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1e+03        |
# |    mean_reward          | 3e+06        |
# | time/                   |              |
# |    total_timesteps      | 44000        |
# | train/                  |              |
# |    approx_kl            | 2.596411e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.86        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.18e+09     |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00011     |
# |    std                  | 1.01         |
# |    value_loss           | 1.61e+09     |
# ------------------------------------------
# Eval num_timesteps=45000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 45000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 22    |
# |    time_elapsed    | 422   |
# |    total_timesteps | 45056 |
# ------------------------------
# Eval num_timesteps=46000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 46000         |
# | train/                  |               |
# |    approx_kl            | 1.9008585e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.05e+08      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -7.7e-05      |
# |    std                  | 1.01          |
# |    value_loss           | 9.52e+08      |
# -------------------------------------------
# Eval num_timesteps=47000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 47000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 23    |
# |    time_elapsed    | 441   |
# |    total_timesteps | 47104 |
# ------------------------------
# Eval num_timesteps=48000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 48000         |
# | train/                  |               |
# |    approx_kl            | 2.0982989e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.9e+08       |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -7.17e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 1.02e+09      |
# -------------------------------------------
# Eval num_timesteps=49000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 49000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 24    |
# |    time_elapsed    | 460   |
# |    total_timesteps | 49152 |
# ------------------------------
# Eval num_timesteps=50000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 3e+06       |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 2.26649e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.86       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.2e+08     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -5.79e-05   |
# |    std                  | 1.01        |
# |    value_loss           | 9.65e+08    |
# -----------------------------------------
# Eval num_timesteps=51000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 51000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 25    |
# |    time_elapsed    | 478   |
# |    total_timesteps | 51200 |
# ------------------------------
# Eval num_timesteps=52000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 52000         |
# | train/                  |               |
# |    approx_kl            | 4.4421176e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.03e+08      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -0.00011      |
# |    std                  | 1.01          |
# |    value_loss           | 7.88e+08      |
# -------------------------------------------
# Eval num_timesteps=53000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 53000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 26    |
# |    time_elapsed    | 498   |
# |    total_timesteps | 53248 |
# ------------------------------
# Eval num_timesteps=54000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 54000         |
# | train/                  |               |
# |    approx_kl            | 8.7183435e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.86         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.31e+08      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -3.31e-05     |
# |    std                  | 1.01          |
# |    value_loss           | 9.14e+08      |
# -------------------------------------------
# Eval num_timesteps=55000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 55000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 27    |
# |    time_elapsed    | 516   |
# |    total_timesteps | 55296 |
# ------------------------------
# Eval num_timesteps=56000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1e+03      |
# |    mean_reward          | 3e+06      |
# | time/                   |            |
# |    total_timesteps      | 56000      |
# | train/                  |            |
# |    approx_kl            | 3.8539e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.87      |
# |    explained_variance   | 1.79e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.15e+08   |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -8.11e-05  |
# |    std                  | 1.01       |
# |    value_loss           | 8.21e+08   |
# ----------------------------------------
# Eval num_timesteps=57000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 57000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 28    |
# |    time_elapsed    | 535   |
# |    total_timesteps | 57344 |
# ------------------------------
# Eval num_timesteps=58000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 58000         |
# | train/                  |               |
# |    approx_kl            | 1.9768486e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.42e+08      |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -7.43e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 9.77e+08      |
# -------------------------------------------
# Eval num_timesteps=59000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 59000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 29    |
# |    time_elapsed    | 555   |
# |    total_timesteps | 59392 |
# ------------------------------
# Eval num_timesteps=60000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 60000         |
# | train/                  |               |
# |    approx_kl            | 1.5565893e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.91e+08      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -4.3e-05      |
# |    std                  | 1.02          |
# |    value_loss           | 1e+09         |
# -------------------------------------------
# Eval num_timesteps=61000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 3e+06    |
# | time/              |          |
# |    total_timesteps | 61000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 30    |
# |    time_elapsed    | 573   |
# |    total_timesteps | 61440 |
# ------------------------------
# Eval num_timesteps=62000, episode_reward=2802788.54 +/- 7508.02
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.8e+06       |
# | time/                   |               |
# |    total_timesteps      | 62000         |
# | train/                  |               |
# |    approx_kl            | 1.5851983e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.04e+08      |
# |    n_updates            | 300           |
# |    policy_gradient_loss | -7.08e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.03e+09      |
# -------------------------------------------
# Eval num_timesteps=63000, episode_reward=2799184.48 +/- 3446.76
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.8e+06  |
# | time/              |          |
# |    total_timesteps | 63000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 31    |
# |    time_elapsed    | 593   |
# |    total_timesteps | 63488 |
# ------------------------------
# Eval num_timesteps=64000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 3e+06         |
# | time/                   |               |
# |    total_timesteps      | 64000         |
# | train/                  |               |
# |    approx_kl            | 3.3048855e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.87         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.71e+08      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -0.000138     |
# |    std                  | 1.02          |
# |    value_loss           | 1.04e+09      |
# -------------------------------------------
# Eval num_timesteps=65000, episode_reward=3003000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ...
# |    loss                 | 3.88e+08      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -0.000116     |
# |    std                  | 1.02          |
# |    value_loss           | 9.38e+08      |
# -------------------------------------------
# Eval num_timesteps=83000, episode_reward=2422183.30 +/- 4389.45
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.42e+06 |
# | time/              |          |
# |    total_timesteps | 83000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 107   |
# |    iterations      | 41    |
# |    time_elapsed    | 781   |
# |    total_timesteps | 83968 |
# ------------------------------
# Eval num_timesteps=84000, episode_reward=2126183.76 +/- 403.12
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.13e+06      |
# | time/                   |               |
# |    total_timesteps      | 84000         |
# | train/                  |               |
# |    approx_kl            | 1.1189259e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.77e+08      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -4.7e-05      |
# |    std                  | 1.02          |
# |    value_loss           | 1.06e+09      |
# -------------------------------------------
# Eval num_timesteps=85000, episode_reward=2126257.35 +/- 277.77
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.13e+06 |
# | time/              |          |
# |    total_timesteps | 85000    |
# ---------------------------------
# Eval num_timesteps=86000, episode_reward=2126074.62 +/- 177.41
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.13e+06 |
# | time/              |          |
# |    total_timesteps | 86000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 42    |
# |    time_elapsed    | 807   |
# |    total_timesteps | 86016 |
# ------------------------------
# Eval num_timesteps=87000, episode_reward=2103620.33 +/- 182.12
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.1e+06       |
# | time/                   |               |
# |    total_timesteps      | 87000         |
# | train/                  |               |
# |    approx_kl            | 2.4287147e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.49e+08      |
# |    n_updates            | 420           |
# |    policy_gradient_loss | -8.78e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 8.97e+08      |
# -------------------------------------------
# Eval num_timesteps=88000, episode_reward=2103642.78 +/- 380.60
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.1e+06  |
# | time/              |          |
# |    total_timesteps | 88000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 43    |
# |    time_elapsed    | 825   |
# |    total_timesteps | 88064 |
# ------------------------------
# Eval num_timesteps=89000, episode_reward=2092185.39 +/- 356.76
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 2.09e+06      |
# | time/                   |               |
# |    total_timesteps      | 89000         |
# | train/                  |               |
# |    approx_kl            | 1.7503335e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.58e+08      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -4.52e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 6.86e+08      |
# -------------------------------------------
# Eval num_timesteps=90000, episode_reward=2092074.17 +/- 350.41
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 2.09e+06 |
# | time/              |          |
# |    total_timesteps | 90000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 44    |
# |    time_elapsed    | 844   |
# |    total_timesteps | 90112 |
# ------------------------------
# Eval num_timesteps=91000, episode_reward=1940025.90 +/- 351.91
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 1.94e+06      |
# | time/                   |               |
# |    total_timesteps      | 91000         |
# | train/                  |               |
# |    approx_kl            | 1.3919489e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.49e+08      |
# |    n_updates            | 440           |
# |    policy_gradient_loss | -6.44e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.48e+09      |
# -------------------------------------------
# Eval num_timesteps=92000, episode_reward=1939660.79 +/- 381.53
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1.94e+06 |
# | time/              |          |
# |    total_timesteps | 92000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 45    |
# |    time_elapsed    | 863   |
# |    total_timesteps | 92160 |
# ------------------------------
# Eval num_timesteps=93000, episode_reward=1972872.79 +/- 4290.21
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 1.97e+06      |
# | time/                   |               |
# |    total_timesteps      | 93000         |
# | train/                  |               |
# |    approx_kl            | 5.7707075e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 1.19e-07      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.63e+08      |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -1.23e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.11e+09      |
# -------------------------------------------
# Eval num_timesteps=94000, episode_reward=1972825.60 +/- 4032.13
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1.97e+06 |
# | time/              |          |
# |    total_timesteps | 94000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 46    |
# |    time_elapsed    | 882   |
# |    total_timesteps | 94208 |
# ------------------------------
# Eval num_timesteps=95000, episode_reward=1904968.65 +/- 499.91
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 1.9e+06       |
# | time/                   |               |
# |    total_timesteps      | 95000         |
# | train/                  |               |
# |    approx_kl            | 2.9858202e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7.61e+08      |
# |    n_updates            | 460           |
# |    policy_gradient_loss | -7.94e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.45e+09      |
# -------------------------------------------
# Eval num_timesteps=96000, episode_reward=1904763.49 +/- 662.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1.9e+06  |
# | time/              |          |
# |    total_timesteps | 96000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 47    |
# |    time_elapsed    | 901   |
# |    total_timesteps | 96256 |
# ------------------------------
# Eval num_timesteps=97000, episode_reward=1803701.76 +/- 1313.36
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 1.8e+06       |
# | time/                   |               |
# |    total_timesteps      | 97000         |
# | train/                  |               |
# |    approx_kl            | 4.3248292e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | 5.96e-08      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.98e+08      |
# |    n_updates            | 470           |
# |    policy_gradient_loss | -1.81e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.54e+09      |
# -------------------------------------------
# Eval num_timesteps=98000, episode_reward=1803359.31 +/- 514.08
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1.8e+06  |
# | time/              |          |
# |    total_timesteps | 98000    |
# ---------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 106   |
# |    iterations      | 48    |
# |    time_elapsed    | 919   |
# |    total_timesteps | 98304 |
# ------------------------------
# Eval num_timesteps=99000, episode_reward=1774601.73 +/- 1145.06
# Episode length: 1000.00 +/- 0.00
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1e+03         |
# |    mean_reward          | 1.77e+06      |
# | time/                   |               |
# |    total_timesteps      | 99000         |
# | train/                  |               |
# |    approx_kl            | 4.7075446e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.88         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.5e+08       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -1.85e-05     |
# |    std                  | 1.02          |
# |    value_loss           | 1.3e+09       |
# -------------------------------------------
# Eval num_timesteps=100000, episode_reward=1771181.53 +/- 3129.23
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1.77e+06 |
# | time/              |          |
# |    total_timesteps | 100000   |
# ---------------------------------
# -------------------------------
# | time/              |        |
# |    fps             | 106    |
# |    iterations      | 49     |
# |    time_elapsed    | 938    |
# |    total_timesteps | 100352 |
# -------------------------------
# mean_reward:1773588.36 +/- 1288.88
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/mean_reward</td><td>██████████████████████████▇█▇▆▅▅▅▃▃▃▂▂▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>time/fps</td><td>█▆▄▃▃▃▃▃▃▃▃▃▃▃▃▃▃▁▁▁▁▁▂▁▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>train/approx_kl</td><td>▇▄▄▁▃▃▂▃▂▂▆▅▃█▃▁▂▃▂▃▅▁▄▃▂▄▂▄▅▁▄▄▂▆▂▂▂▁▄▁</td></tr><tr><td>train/clip_fraction</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>██▇▇▇▆▆▆▆▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>train/explained_variance</td><td>▁█▄▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▅▃▃▂▂▅▃▃▃▂▃▂▂▃▁▂▃█▂▄▁▂▁▂▂▄▃▂▂▃▂▃▃▂▂▁▅▄▅▄</td></tr><tr><td>train/policy_gradient_loss</td><td>▄▄▅█▆▆▇▅▆▇▃▃▆▁▆█▆▄▅▆▄▇▅▆▇▃▆▄▄▇▆▄▆▄▇▇▆█▅█</td></tr><tr><td>train/std</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▇▇▇███████</td></tr><tr><td>train/value_loss</td><td>▅▄▅▁▆▃▃▄▄▁▃▃▄▄▂▃▅█▃▃▂▃▂▃▃▄▄▃▃▄▂█▄▃▄▁▇▄▇▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>1000.0</td></tr><tr><td>eval/mean_reward</td><td>1771181.5</td></tr><tr><td>global_step</td><td>100352</td></tr><tr><td>time/fps</td><td>106.0</td></tr><tr><td>train/approx_kl</td><td>0.0</td></tr><tr><td>train/clip_fraction</td><td>0.0</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-2.88145</td></tr><tr><td>train/explained_variance</td><td>-0.0</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>650462272.0</td></tr><tr><td>train/policy_gradient_loss</td><td>-2e-05</td></tr><tr><td>train/std</td><td>1.02234</td></tr><tr><td>train/value_loss</td><td>1298470528.0</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">azure-energy-36</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/eozno2tt' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/eozno2tt</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_191819-eozno2tt/logs</code>

# %% [markdown]
# # B - A2C Algorithm - Advantage Actor Critic (A2C)
#
# A2C is a policy gradient algorithm and it is part of the on-policy family. That means that we are learning the value function for one policy while following it, or in other words, we can’t learn the value function by following another policy.

# %% [markdown]
# ### Experiment#3 - Running A2C algorithm over 100 time steps
#
# Experiment A2C algo with with default params - gamma=0.99 , learning_rate=0.0007 , ent_coef=0.4

# %%
from stocktrade import Stocktrade

if __name__ == "__main__":
    timesteps = 100
    algo = "A2C"
    Stocktrade.stocktrade(algo,timesteps)
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_193436-24mihd74</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/24mihd74' target="_blank">rare-tree-37</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/24mihd74' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/24mihd74</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cuda device
# Logging to runs/24mihd74/A2C_1
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:855945.31 +/- 2283.12
# /content/trading-bot/env/stock_trading_env.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   self.cost_basis = (
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">rare-tree-37</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/24mihd74' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/24mihd74</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_193436-24mihd74/logs</code>

# %% [markdown]
# ### Experiment#4 - A2C over 100 steps (Hyper Parameter Tuning)
#
# **Experiment A2C algo with gamma=0.8 , learning_rate=0.000010 , ent_coef=0.3**

# %%
#### 6.2  Running A2C algorithm over 100 time steps
from stocktrade1 import Stocktrade

if __name__ == "__main__":
    timesteps = 100
    algo = "A2C"
    hyper_param = True
    Stocktrade.stocktrade(algo,timesteps,hyper_param)
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_193517-o8h0hx80</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/o8h0hx80' target="_blank">decent-forest-38</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/o8h0hx80' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/o8h0hx80</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cuda device
# Logging to runs/o8h0hx80/A2C_1
# /content/trading-bot/env/stock_trading_env.py:103: RuntimeWarning: invalid value encountered in double_scalars
#   self.cost_basis = (
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:3003000.00 +/- 0.00
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">decent-forest-38</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/o8h0hx80' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/o8h0hx80</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_193517-o8h0hx80/logs</code>

# %% [markdown]
# # C - SAC Algorithm - Soft Actor Critic (SAC) Off-Policy Maximum Entropy Deep Reinforcement Learning with a Stochastic Actor.
#
# Soft Actor Critic, or SAC, is an off-policy actor-critic deep RL algorithm based on the maximum entropy reinforcement learning framework. In this framework, the actor aims to maximize expected reward while also maximizing entropy. That is, to succeed at the task while acting as randomly as possible.

# %% [markdown]
# ###Experiment#5 - Running SAC algorithm over 100 time steps
#
# Experiment SAC algo with with default params - gamma=0.99 , learning_rate=0.0007 , ent_coef=0.4

# %%
#### 6.3 Running SAC algorithm over 100 time steps
from stocktrade import Stocktrade

if __name__ == "__main__":
    timesteps = 100
    algo = "SAC"
    Stocktrade.stocktrade(algo,timesteps)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668736083336928, max=1.0…
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_193555-nvm568ua</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/nvm568ua' target="_blank">rural-star-39</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/nvm568ua' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/nvm568ua</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cuda device
# Logging to runs/nvm568ua/SAC_1
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:3003000.00 +/- 0.00
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">rural-star-39</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/nvm568ua' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/nvm568ua</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_193555-nvm568ua/logs</code>

# %% [markdown]
# ###Experiment#6 - A2C over 100 steps (Hyper Parameter Tuning)
#
# **Experiment SAC algo with gamma=0.8 , learning_rate=0.000010 , ent_coef=0.3**

# %%
from stocktrade1 import Stocktrade

if __name__ == "__main__":
    timesteps = 100
    algorithm = "SAC"
    hparam = "T"
    Stocktrade.stocktrade(algorithm,timesteps,hparam)
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/content/trading-bot/wandb/run-20230321_193633-57wi8sys</code>
# Syncing run <strong><a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/57wi8sys' target="_blank">sage-dragon-40</a></strong> to <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading</a>
#  View run at <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/57wi8sys' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/57wi8sys</a>
# /usr/local/lib/python3.9/dist-packages/gym/spaces/box.py:73: UserWarning: WARN: Box bound precision lowered by casting to float16
#   logger.warn(
# wandb: WARNING When using several event log directories, please call `wandb.tensorboard.patch(root_logdir="...")` before `wandb.init`
# Using cuda device
# Logging to runs/57wi8sys/SAC_1
# /usr/local/lib/python3.9/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward:3003000.00 +/- 0.00
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
#  View run <strong style="color:#cdcd00">sage-dragon-40</strong> at: <a href='https://wandb.ai/rachanakukkikatte21/StockTrading/runs/57wi8sys' target="_blank">https://wandb.ai/rachanakukkikatte21/StockTrading/runs/57wi8sys</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 3 other file(s)
# Find logs at: <code>./wandb/run-20230321_193633-57wi8sys/logs</code>

# %% [markdown]
# ##Run this first to hyperparamer experiments

# %%
# %%writefile /content/trading-bot//stocktrade1.py

import argparse
import sys
# from stable_baselines3.common.policies import MlpPolicy
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3 import PPO, A2C , SAC

from stable_baselines3.common.callbacks import CallbackList, CheckpointCallback
from stable_baselines3.common.callbacks import EvalCallback 
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env

import pandas as pd
import wandb
from wandb.integration.sb3 import WandbCallback
from env.stock_trading_env import StockTradingEnv


TOTAL_TIMESTEPS = 100000 # 1000000 for PPO, 100 for A2C , 100 for SAC 

class Stocktrade:
    
    def stocktrade(algo,timesteps,hparam ):
    
        config = {
             "policy_type": "MlpPolicy",
             "total_timesteps": timesteps,
             "learning_rate": 0.01,
              "momentum" : 0.2,
              "env_name": "stock-v0",
             }
         
         # Initialize wandb
        run = wandb.init(
               project="StockTrading",
               config=config,
               sync_tensorboard=True,  # auto-upload StockTrading's tensorboard metrics
               monitor_gym=True,  # auto-upload the videos of agents playing the game
               save_code=True,  # optional
             )
     
        # Load data
        df = pd.read_csv('./data/AAPL.csv')
        df = df.sort_values('Date')
     
        # The algorithms require a vectorized environment to run
        env = DummyVecEnv([lambda: StockTradingEnv(df)])
         
         # env = make_vec_env([lambda: StockTradingEnv(df)],n_envs=10)
         # print("Check env: ",check_env(StockTradingEnv(df)))
         
         # Instantiate the agent model
        if algo == "PPO":
          if hparam == "T":
               model = PPO(config["policy_type"],env,gamma=0.80,learning_rate=0.000010,ent_coef=0.3, verbose=1, tensorboard_log=f"runs/{run.id}")
          else: 
               model = PPO(config["policy_type"],env, verbose=1, tensorboard_log=f"runs/{run.id}")
     
        elif algo == "A2C":
          if hparam == 'T':
             model = A2C(config["policy_type"],env,gamma=0.80 , learning_rate=0.000010 , ent_coef=0.3,verbose=1, tensorboard_log=f"runs/{run.id}")
          else:
             model = A2C(config["policy_type"],env, verbose=1, tensorboard_log=f"runs/{run.id}")
                
        elif algo == "SAC":
          policy_kwargs = dict(net_arch=dict(pi=[64, 64], qf=[400, 300]))

          if hparam == 'T':
             model = SAC(config["policy_type"], env, gamma=0.80 , learning_rate=0.000010 , ent_coef=0.3, policy_kwargs=policy_kwargs, verbose=1,tensorboard_log=f"runs/{run.id}" )
          else:
             model = SAC(config["policy_type"], env, policy_kwargs=policy_kwargs, verbose=1,tensorboard_log=f"runs/{run.id}" )

        else:
             print("Program Terminated. Please enter valid algorithm - PPO / A2C / SAC")
             sys.exit()
     
        checkpoint_callback = CheckpointCallback(save_freq=1e4, save_path='./model_checkpoints/')
        eval_callback = EvalCallback(env,
                                      best_model_save_path=f"./model_checkpoints/best_model/",
                                      log_path="./logs/results",
                                      eval_freq=1000,verbose=1)
        wandb_callback = WandbCallback(
             model_save_path=f"models/{run.id}",
                         # gradient_save_freq=1000
             verbose=1,
             )
         # Create the callback list
        callback = CallbackList([checkpoint_callback, eval_callback,wandb_callback])
         
         # Train the agent
        model.learn(
             total_timesteps=config["total_timesteps"],
             callback=callback,
             )
         # print rewards
        mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
        print(f"mean_reward:{mean_reward:.2f} +/- {std_reward:.2f}")
     
        obs = env.reset()
     
        for i in range(200):
             action, _states = model.predict(obs)
             obs, rewards, done, info = env.step(action)
             env.render(mode='file')
        env.render(mode='static')
        run.finish()


if __name__ == '__main__':
    # Initialize parser
    parser = argparse.ArgumentParser(description='Stock Trade Inference')
    parser.add_argument('-a', "--algorithm", type=str, required=True,
                        default="PPO", help="mention algorithm  - PPO / A2C / SAC")
    parser.add_argument('-t', "--timesteps", type=int, required=True,
                        default="PPO", help="enter timesteps")
    parser.add_argument('-h', "--hparam", type=str, required=True,
                        default="F", help="enter T/F")
    args = parser.parse_args()
    algo = args.algorithm
    timesteps = args.timesteps
    hparam = args.hparam
    print("hparam:", hparam)
    Stocktrade.stocktrade(algo,timesteps,hparam)
# Out:
# Overwriting /content/trading-bot//stocktrade1.py
